# %% [markdown]
# ## USGS RECTANGULAR DATA [7.014, 62.104] Latitude, [-257.695, -65] Longitude between 1993 - Now

# %%
import pandas as pd

merge_me1 = pd.read_csv("../../data/raw/usgs-data/1993-01-01_1996-12-31.csv")
merge_me2 = pd.read_csv("../../data/raw/usgs-data/1997-01-01_1999-12-31.csv")
merge_me3 = pd.read_csv("../../data/raw/usgs-data/2000-01-01_2002-12-31.csv")
merge_me4 = pd.read_csv("../../data/raw/usgs-data/2003-01-01_2004-12-31.csv")
merge_me5 = pd.read_csv("../../data/raw/usgs-data/2005-01-01_2006-12-31.csv")
merge_me6 = pd.read_csv("../../data/raw/usgs-data/2007-01-01_2007-12-31.csv")
merge_me7 = pd.read_csv("../../data/raw/usgs-data/2008-01-01_2009-12-31.csv")
merge_me8 = pd.read_csv("../../data/raw/usgs-data/2010-01-01_2010-12-31.csv")
merge_me9 = pd.read_csv("../../data/raw/usgs-data/2011-01-01_2012-12-31.csv")
merge_me10 = pd.read_csv("../../data/raw/usgs-data/2013-01-01_2014-12-31.csv")
merge_me11 = pd.read_csv("../../data/raw/usgs-data/2015-01-01_2016-12-31.csv")
merge_me12 = pd.read_csv("../../data/raw/usgs-data/2017-01-01_2018-12-31.csv")
merge_me13 = pd.read_csv("../../data/raw/usgs-data/2019-01-01_2020-12-31.csv")
merge_me14 = pd.read_csv("../../data/raw/usgs-data/2021-01-01_2022-12-31.csv")
merge_me15 = pd.read_csv("../../data/raw/usgs-data/2023-01-01_now.csv")

merge_me1
# Out:
#                            time  latitude  longitude  depth  mag magType  nst  \
# 0      1993-01-01T02:54:42.710Z   35.1960   111.0310   10.0  3.9      mb  NaN
# 1      1993-01-01T04:12:28.960Z   60.2248  -152.7263   10.2  3.1      ml  NaN
# 2      1993-01-01T04:30:08.470Z   53.2260   157.6020  169.7  4.2      mb  NaN
# 3      1993-01-01T05:08:05.200Z   35.8780   -82.0860    2.3  3.0      md  NaN
# 4      1993-01-01T05:36:55.770Z   30.5650  -113.9890   10.0  3.6      mb  NaN
# ...                         ...       ...        ...    ...  ...     ...  ...
# 17952  1996-12-31T15:58:04.280Z   24.7330   127.6320   42.6  4.1      mb  NaN
# 17953  1996-12-31T17:18:33.670Z   53.0942  -167.1083   25.1  3.0      ml  NaN
# 17954  1996-12-31T19:30:02.630Z   40.4560   143.5700   33.0  4.8      mb  NaN
# 17955  1996-12-31T23:39:25.900Z   53.4150   142.7260   33.0  4.8      mb  NaN
# 17956  1996-12-31T23:53:33.190Z   27.9980   143.4670   33.0  4.3      mb  NaN
#
#          gap     dmin   rms  ...                   updated  \
# 0        NaN      NaN  1.10  ...  2014-11-07T00:52:08.517Z
# 1        NaN      NaN  0.33  ...  2020-09-14T19:53:28.358Z
# 2        NaN      NaN  0.40  ...  2014-11-07T00:52:08.693Z
# 3      115.0  0.56657  0.30  ...  2022-06-28T14:22:58.419Z
# 4        NaN      NaN  0.80  ...  2016-02-09T22:30:38.915Z
# ...      ...      ...   ...  ...                       ...
# 17952    NaN      NaN  0.83  ...  2014-11-07T01:01:51.129Z
# 17953    NaN      NaN  0.25  ...  2020-09-14T21:54:15.341Z
# 17954    NaN      NaN  1.12  ...  2014-11-07T01:01:51.159Z
# 17955    NaN      NaN  0.91  ...  2014-11-07T01:01:51.173Z
# 17956    NaN      NaN  1.38  ...  2014-11-07T01:01:51.178Z
#
#                                          place        type horizontalError  \
# 0                   19 km N of Yuncheng, China  earthquake             NaN
# 1               61 km WNW of Ninilchik, Alaska  earthquake             NaN
# 2                  52 km W of Yelizovo, Russia  earthquake             NaN
# 3      4 km SSW of Spruce Pine, North Carolina  earthquake             NaN
# 4          93 km SSW of Puerto Peñasco, Mexico  earthquake             NaN
# ...                                        ...         ...             ...
# 17952                154 km S of Itoman, Japan  earthquake             NaN
# 17953            94 km SSW of Unalaska, Alaska  earthquake             NaN
# 17954              165 km ENE of Miyako, Japan  earthquake             NaN
# 17955                15 km W of Tungor, Russia  earthquake             NaN
# 17956              Bonin Islands, Japan region  earthquake             NaN
#
#       depthError  magError  magNst    status  locationSource magSource
# 0            NaN       NaN     1.0  reviewed              us        us
# 1            0.4       NaN     NaN  reviewed              ak        ak
# 2           26.8       NaN     6.0  reviewed              us        us
# 3            2.1       NaN     NaN  reviewed              nm        nm
# 4            NaN       NaN     1.0  reviewed              us        us
# ...          ...       ...     ...       ...             ...       ...
# 17952        NaN       NaN     3.0  reviewed              us        us
# 17953       52.8       NaN     NaN  reviewed              ak        ak
# 17954        NaN       NaN     5.0  reviewed              us        us
# 17955        NaN       NaN     7.0  reviewed              us        us
# 17956        NaN       NaN     4.0  reviewed              us        us
#
# [17957 rows x 22 columns]

# %%
dataframes = [merge_me1, merge_me2, merge_me3, merge_me4, merge_me5, 
              merge_me6, merge_me7, merge_me8, merge_me9, merge_me10, 
              merge_me11, merge_me12, merge_me13, merge_me14, merge_me15]

full_earthquake_data = pd.concat(dataframes, ignore_index=True)
unique_earthquake_data = full_earthquake_data.drop_duplicates(subset='id')
unique_earthquake_data.rename(columns={
    'id': 'Event ID',
    'time': 'Datetime',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'depth': 'Depth(km)',
    'mag': 'xM'
}, inplace=True)

unique_earthquake_data['Datetime'] = pd.to_datetime(unique_earthquake_data['Datetime']).dt.strftime('%d/%m/%Y %H:%M:%S')
df_converted =  unique_earthquake_data[['Event ID', 'Datetime', 'Latitude', 'Longitude', 'Depth(km)', 'xM']]
df_converted
# Out:
#             Event ID             Datetime  Latitude  Longitude  Depth(km)   xM
# 0         usp0005k5s  01/01/1993 02:54:42   35.1960   111.0310      10.00  3.9
# 1        ak9931pzpqo  01/01/1993 04:12:28   60.2248  -152.7263      10.20  3.1
# 2         usp0005k5y  01/01/1993 04:30:08   53.2260   157.6020     169.70  4.2
# 3            se61290  01/01/1993 05:08:05   35.8780   -82.0860       2.30  3.0
# 4         usp0005k64  01/01/1993 05:36:55   30.5650  -113.9890      10.00  3.6
# ...              ...                  ...       ...        ...        ...  ...
# 212221    us6000nqml  09/09/2024 13:18:56   22.4729   121.8432      10.00  4.4
# 212222    us6000nqp5  09/09/2024 16:25:17   51.5773   177.8293      60.66  3.8
# 212223  ak024bmotm5n  09/09/2024 16:55:40   60.0019  -146.2138      20.40  3.5
# 212224  ak024bmotrix  09/09/2024 16:55:41   60.0269  -146.2638       7.80  3.3
# 212225    us6000nqre  09/09/2024 19:31:28   17.8394   119.8370      10.00  4.5
#
# [212226 rows x 6 columns]

# %%
df_converted.to_csv("../../data/cleaned/usgs_93_now_rectangular_region.csv")

# %%
from src.util import earthquake_filter_utils
df_large = earthquake_filter_utils.magnitude_filter(df_converted, 5.5)
df_large
# Out:
#           Event ID             Datetime  Latitude  Longitude  Depth(km)   xM
# 89      usp0005kqb  13/01/1993 17:11:07   17.9550   -76.5830     16.000  5.5
# 104     usp0005kth  15/01/1993 11:06:01   42.9820   144.1650    112.300  6.1
# 105     usp0005ktj  15/01/1993 11:06:05   43.3000   143.6910    102.200  7.6
# 125     usp0005kwn  18/01/1993 01:18:06   18.4140   145.7340    151.100  6.4
# 139     usp0005kz3  19/01/1993 14:39:26   38.6490   133.4650    448.300  6.6
# ...            ...                  ...       ...        ...        ...  ...
# 211967  us7000n7v7  19/08/2024 03:39:00   12.7336   124.7630     42.108  5.7
# 212010  us7000n8ki  21/08/2024 23:30:34   52.9158   160.1094     30.000  5.5
# 212058  us7000n9fn  26/08/2024 05:08:44    7.4234   -82.2904     10.000  5.8
# 212086  us6000nncs  28/08/2024 21:57:56   12.9980   -89.5623     33.882  6.1
# 212099  us6000nnlx  30/08/2024 04:24:23   52.9702   160.3687     27.858  6.0
#
# [4161 rows x 6 columns]

# %%
df_converted['Datetime'] = pd.to_datetime(df_converted['Datetime'], format="%d/%m/%Y %H:%M:%S")

df_converted =  (df_converted[df_converted['Datetime'] >= pd.Timestamp('1993-01-01')]).sort_values('Datetime', ascending=True)
df_converted
# Out:
# C:\Users\M13\AppData\Local\Temp\ipykernel_10868\2277187866.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_converted['Datetime'] = pd.to_datetime(df_converted['Datetime'], format="%d/%m/%Y %H:%M:%S")
#             Event ID            Datetime  Latitude  Longitude  Depth(km)   xM
# 0         usp0005k5s 1993-01-01 02:54:42   35.1960   111.0310      10.00  3.9
# 1        ak9931pzpqo 1993-01-01 04:12:28   60.2248  -152.7263      10.20  3.1
# 2         usp0005k5y 1993-01-01 04:30:08   53.2260   157.6020     169.70  4.2
# 3            se61290 1993-01-01 05:08:05   35.8780   -82.0860       2.30  3.0
# 4         usp0005k64 1993-01-01 05:36:55   30.5650  -113.9890      10.00  3.6
# ...              ...                 ...       ...        ...        ...  ...
# 212221    us6000nqml 2024-09-09 13:18:56   22.4729   121.8432      10.00  4.4
# 212222    us6000nqp5 2024-09-09 16:25:17   51.5773   177.8293      60.66  3.8
# 212223  ak024bmotm5n 2024-09-09 16:55:40   60.0019  -146.2138      20.40  3.5
# 212224  ak024bmotrix 2024-09-09 16:55:41   60.0269  -146.2638       7.80  3.3
# 212225    us6000nqre 2024-09-09 19:31:28   17.8394   119.8370      10.00  4.5
#
# [212226 rows x 6 columns]

# %%
import numpy as np

def lat_lon_to_cartesian(lat, lon, R=6371.0):
    # Convert latitude and longitude from degrees to radians
    lat_rad = np.radians(lat)
    lon_rad = np.radians(lon)
    
    # Calculate x, y, z coordinates
    x = R * np.cos(lat_rad) * np.cos(lon_rad)
    y = R * np.cos(lat_rad) * np.sin(lon_rad)
    z = R * np.sin(lat_rad)
    
    return np.array([x, y, z])

def spherical_vector(lat1, lon1, lat2, lon2):
    # Convert points to Cartesian coordinates
    p1 = lat_lon_to_cartesian(lat1, lon1)
    p2 = lat_lon_to_cartesian(lat2, lon2)
    
    # Calculate Cartesian difference vector
    d_cartesian = p2 - p1
    
    # The resulting vector contains x, y, and z components
    return d_cartesian

# This function adds cartesian coordinate system components as new columns to the df
def lat_lon_to_cartesian_vectorized(df, R=6371.0):
    lat_rad = np.radians(df['Latitude'].values)
    lon_rad = np.radians(df['Longitude'].values)
    
    x = R * np.cos(lat_rad) * np.cos(lon_rad)
    y = R * np.cos(lat_rad) * np.sin(lon_rad)
    z = R * np.sin(lat_rad)
    
    df_copy = df.copy()
    df_copy['X'] = x
    df_copy['Y'] = y
    df_copy['Z'] = z
    
    return df_copy

# %%
df_converted = lat_lon_to_cartesian_vectorized(df_converted)
df_converted
# Out:
#             Event ID            Datetime  Latitude  Longitude  Depth(km)   xM  \
# 0         usp0005k5s 1993-01-01 02:54:42   35.1960   111.0310      10.00  3.9
# 1        ak9931pzpqo 1993-01-01 04:12:28   60.2248  -152.7263      10.20  3.1
# 2         usp0005k5y 1993-01-01 04:30:08   53.2260   157.6020     169.70  4.2
# 3            se61290 1993-01-01 05:08:05   35.8780   -82.0860       2.30  3.0
# 4         usp0005k64 1993-01-01 05:36:55   30.5650  -113.9890      10.00  3.6
# ...              ...                 ...       ...        ...        ...  ...
# 212221    us6000nqml 2024-09-09 13:18:56   22.4729   121.8432      10.00  4.4
# 212222    us6000nqp5 2024-09-09 16:25:17   51.5773   177.8293      60.66  3.8
# 212223  ak024bmotm5n 2024-09-09 16:55:40   60.0019  -146.2138      20.40  3.5
# 212224  ak024bmotrix 2024-09-09 16:55:41   60.0269  -146.2638       7.80  3.3
# 212225    us6000nqre 2024-09-09 19:31:28   17.8394   119.8370      10.00  4.5
#
#                   X            Y            Z
# 0      -1868.395728  4859.477002  3672.086828
# 1      -2812.097715 -1449.797564  5529.903658
# 2      -3526.328461  1453.303707  5103.190857
# 3        710.766894 -5113.043689  3733.796414
# 4      -2230.300490 -5011.926288  3239.752400
# ...             ...          ...          ...
# 212221 -3106.060023  5001.138434  2435.291873
# 212222 -3956.469202   149.966004  4991.342770
# 212223 -2647.375698 -1771.340316  5517.553480
# 212224 -2646.918149 -1767.692156  5518.942811
# 212225 -3017.383766  5260.768572  1951.755682
#
# [212226 rows x 9 columns]

# %%
from src.util import earthquake_filter_utils
from src.util import math_utils

def distance_filter_numpy(df, event_id, radius_km=10):
    event_lat = earthquake_filter_utils.get_value_from_eid(df, event_id, "Latitude")
    event_lon = earthquake_filter_utils.get_value_from_eid(df, event_id, "Longitude")

    # Get latitudes and longitudes as NumPy arrays
    lats = df['Latitude'].values
    lons = df['Longitude'].values

    # Vectorized haversine computation
    distances = math_utils.haversine(event_lat, event_lon, lats, lons)
    
    # Filter distances within the radius
    mask = distances <= radius_km
    return df[mask]

# %%
def past_earthquakes_filter_numpy(df, event_id, num_earthquakes=30):
    event_datetime = earthquake_filter_utils.get_value_from_eid(df, event_id, "Datetime")
    
    # Convert 'Datetime' column to NumPy array for fast access
    datetimes = df['Datetime'].values

    # Ensure 'datetimes' is in np.datetime64 format
    if datetimes.dtype != 'datetime64[ns]':
        datetimes = datetimes.astype('datetime64[ns]')

    # Filter for earthquakes that happened before the target event
    past_indices = np.where(datetimes < event_datetime)[0]

    # Raise an error if fewer than num_earthquakes exist
    if len(past_indices) < num_earthquakes:
        raise ValueError(f"PAST EARTHQUAKE ERROR: {event_id} with only {len(past_indices)} past earthquakes available.")
    
    # Sort the past earthquakes in chronological order (oldest to newest)
    sorted_indices = past_indices[np.argsort(datetimes[past_indices])]

    # Select the most recent 'num_earthquakes' from the sorted past earthquakes
    selected_indices = sorted_indices[-num_earthquakes:]

    # Get the row corresponding to the event itself (to append it later)
    event_row = df[df['Event ID'] == event_id]

    # Concatenate the past earthquakes and the target event
    result_df = pd.concat([df.iloc[selected_indices], event_row], ignore_index=True)

    # Return the resulting DataFrame (length will be num_earthquakes + 1)
    return result_df

# %%
def time_filter_numpy(df, event_id, years=30):
    event_datetime = earthquake_filter_utils.get_value_from_eid(df, event_id, "Datetime")

    # Ensure the event_datetime is in NumPy datetime64 format
    if not isinstance(event_datetime, np.datetime64):
        event_datetime = np.datetime64(event_datetime)

    hours = int(years * 365.25 * 24)
    
    # Calculate the cutoff time using hours
    cutoff_time = event_datetime - np.timedelta64(hours, 'h')

    datetimes = df['Datetime'].values

    if datetimes.dtype != 'datetime64[ns]':
        datetimes = datetimes.astype('datetime64[ns]')

    # Perform the filtering: Get earthquakes before the event but after the cutoff time
    mask = (datetimes <= event_datetime) & (datetimes >= cutoff_time)
    return df[mask]

# %%
def space_time_filter_numpy(df, event_id, radius_km=10, past_years=30, num_earthquakes=30):
    filtered_df = distance_filter_numpy(df, event_id, radius_km)
    filtered_df = time_filter_numpy(filtered_df, event_id, past_years)
    filtered_df = past_earthquakes_filter_numpy(filtered_df, event_id, num_earthquakes)
    return filtered_df.iloc[:-1], filtered_df.iloc[-1] # past_s_earthquakes, target earthquake

# %%
def get_row_property_numpy(df, idx_array):
    # Convert columns to NumPy arrays for faster access
    event_ids = df['Event ID'].values
    magnitudes = df['xM'].values
    depths = df['Depth(km)'].values
    X_coords = df['X'].values
    Y_coords = df['Y'].values
    Z_coords = df['Z'].values
    dates = df['Datetime'].values

    # Retrieve all properties in one call using NumPy indexing
    return np.array([
        event_ids[idx_array], 
        magnitudes[idx_array], 
        depths[idx_array], 
        X_coords[idx_array], 
        Y_coords[idx_array], 
        Z_coords[idx_array], 
        dates[idx_array]
    ])

# %%
def get_sample_from_eid_numpy(df, event_id, radius=10, past_years=30, num_earthquakes=30, big_eq_min_magnitude=5.5):
    sample_of_eid, target_earthquake = space_time_filter_numpy(df, event_id, radius, past_years, num_earthquakes)
    properties = sample_of_eid[['xM', 'Depth(km)', 'X', 'Y', 'Z', 'Datetime']].values
    
    # Calculate differences between consecutive rows for all columns except Event ID
    differences = np.diff(properties, axis=0)
    
    # Extract datetime differences and calculate time differences in hours
    datetime_col = properties[:, 5]
    time_diffs_hours = np.diff(datetime_col).astype('timedelta64[s]').astype(float) / 3600.0

    differences[:, 5] = time_diffs_hours
    X_eid = differences

    # Determine y_eid: 1 if target earthquake magnitude >= big_eq_min_magnitude, otherwise 0
    y_eid = 1 if target_earthquake['xM'] >= big_eq_min_magnitude else 0
    
    return X_eid, y_eid

# %%
def get_aftershocks_from_eq_numpy(df, event_id, radius=10, big_eq_min_magnitude=5.5):
    event_mag = earthquake_filter_utils.get_value_from_eid(df, event_id, "xM")
    if event_mag < big_eq_min_magnitude:
        raise ValueError(f"Earthquake magnitude should be at least {big_eq_min_magnitude}. Given event_id={event_id}, xM={event_mag}")
    
    aftershock_duration_in_hours = 10 ** (event_mag - 3.0) * 24  ## FIXME: This might be wrong
    event_datetime = earthquake_filter_utils.get_value_from_eid(df, event_id, "Datetime")
    end_time = event_datetime + np.timedelta64(int(aftershock_duration_in_hours), 'h')
    datetimes = df['Datetime'].values
    latitudes = df['Latitude'].values
    longitudes = df['Longitude'].values

    event_lat = earthquake_filter_utils.get_value_from_eid(df, event_id, "Latitude")
    event_lon = earthquake_filter_utils.get_value_from_eid(df, event_id, "Longitude")

    distances = math_utils.haversine(event_lat, event_lon, latitudes, longitudes)
    distance_mask = distances <= radius

    time_mask = (datetimes > event_datetime) & (datetimes <= end_time)

    combined_mask = distance_mask & time_mask
    return df[combined_mask]

# %%
def remove_all_aftershocks_from_data_numpy(df, radius=10, big_eq_min_magnitude=5.5):
    # Create a copy of the original DataFrame to avoid modifying it
    df_copy = df.copy()

    # Filter large earthquakes based on the magnitude threshold
    df_large_eqs = df_copy[df_copy["xM"] >= big_eq_min_magnitude]

    # Create an empty mask for aftershocks
    aftershock_mask = np.zeros(len(df_copy), dtype=bool)

    # Convert 'Event ID' to a NumPy array for faster access
    event_ids = df_copy['Event ID'].values

    # Loop through each large earthquake and use the helper function to find aftershocks
    for event_id in df_large_eqs['Event ID']:
        # Use the helper function get_aftershocks_from_eq_numpy to find aftershocks
        aftershocks_df = get_aftershocks_from_eq_numpy(df_copy, event_id, radius, big_eq_min_magnitude)

        # Get the 'Event ID' values for the aftershocks and mark them in the mask
        aftershock_event_ids = aftershocks_df['Event ID'].values
        aftershock_mask |= np.isin(event_ids, aftershock_event_ids)

    # Use the aftershock mask to remove aftershocks from the copied DataFrame
    df_without_aftershocks = df_copy[~aftershock_mask]

    return df_without_aftershocks

# %%
import torch

def create_classification_data_random(df, total_samples, radius=10, past_years=30, num_earthquakes=30, big_eq_min_magnitude=5.5):
    df = df.reset_index(drop=True)
    selected_indices = np.random.choice(df.index, total_samples, replace=False)
    
    X_samples = []
    y_samples = []
    for idx in selected_indices:
        event_id = df.loc[idx, 'Event ID'] 
        try:
            X_eid, y_eid = get_sample_from_eid_numpy(df, event_id, radius, past_years, num_earthquakes, big_eq_min_magnitude)

            X_samples.append(X_eid)
            y_samples.append(y_eid)
        except Exception as e:
            print(f"Error processing event ID {event_id}: {e}")
            continue

    X_np = np.array(X_samples, dtype=np.float32) 
    y_np = np.array(y_samples, dtype=np.float32) 

    X_tensor = torch.tensor(X_np, dtype=torch.float32)
    y_tensor = torch.tensor(y_np, dtype=torch.float32)

    return X_tensor, y_tensor

# %%
def create_classification_data(df, large_eq_df, radius=10, past_years=30, num_earthquakes=30, big_eq_min_magnitude=5.5, ):
    mag_eids = large_eq_df['Event ID']  # Assumed 'Event ID' column exists in test_df

    X_samples = []
    y_samples = []

    for eid in mag_eids:
        try: 
            X_eid, y_eid = get_sample_from_eid_numpy(df, eid, radius, past_years, num_earthquakes, big_eq_min_magnitude)
            X_samples.append(X_eid)
            y_samples.append(y_eid)
        except Exception as e:
            print(f"Error processing event ID {eid}: {e}")
            continue

    X_np = np.array(X_samples, dtype=np.float32)  
    y_np = np.array(y_samples, dtype=np.float32)  

    X_tensor = torch.tensor(X_np, dtype=torch.float32)
    y_tensor = torch.tensor(y_np, dtype=torch.float32)
    return X_tensor, y_tensor

# %%
x_sample_test, y_sample_test = create_classification_data(df_converted, df_large, num_earthquakes=20)
torch.sum(y_sample_test == 1).item()
# Out:
# Error processing event ID usp0005kqb: PAST EARTHQUAKE ERROR: usp0005kqb with only 0 past earthquakes available.
# Error processing event ID usp0005kth: PAST EARTHQUAKE ERROR: usp0005kth with only 0 past earthquakes available.
# Error processing event ID usp0005ktj: PAST EARTHQUAKE ERROR: usp0005ktj with only 0 past earthquakes available.
# Error processing event ID usp0005kwn: PAST EARTHQUAKE ERROR: usp0005kwn with only 0 past earthquakes available.
# Error processing event ID usp0005kz3: PAST EARTHQUAKE ERROR: usp0005kz3 with only 0 past earthquakes available.
# Error processing event ID usp0005m4g: PAST EARTHQUAKE ERROR: usp0005m4g with only 0 past earthquakes available.
# Error processing event ID usp0005m59: PAST EARTHQUAKE ERROR: usp0005m59 with only 0 past earthquakes available.
# Error processing event ID usp0005mj9: PAST EARTHQUAKE ERROR: usp0005mj9 with only 0 past earthquakes available.
# Error processing event ID usp0005mjw: PAST EARTHQUAKE ERROR: usp0005mjw with only 0 past earthquakes available.
# Error processing event ID usp0005mmn: PAST EARTHQUAKE ERROR: usp0005mmn with only 1 past earthquakes available.
# Error processing event ID usp0005mna: PAST EARTHQUAKE ERROR: usp0005mna with only 2 past earthquakes available.
# Error processing event ID usp0005mnb: PAST EARTHQUAKE ERROR: usp0005mnb with only 1 past earthquakes available.
# Error processing event ID usp0005mrp: PAST EARTHQUAKE ERROR: usp0005mrp with only 0 past earthquakes available.
# Error processing event ID usp0005mu6: PAST EARTHQUAKE ERROR: usp0005mu6 with only 0 past earthquakes available.
# Error processing event ID usp0005nff: PAST EARTHQUAKE ERROR: usp0005nff with only 0 past earthquakes available.
# Error processing event ID usp0005nfz: PAST EARTHQUAKE ERROR: usp0005nfz with only 4 past earthquakes available.
# Error processing event ID usp0005ng2: PAST EARTHQUAKE ERROR: usp0005ng2 with only 6 past earthquakes available.
# Error processing event ID usp0005nnq: PAST EARTHQUAKE ERROR: usp0005nnq with only 0 past earthquakes available.
# Error processing event ID usp0005nrs: PAST EARTHQUAKE ERROR: usp0005nrs with only 0 past earthquakes available.
# Error processing event ID usp0005p0k: PAST EARTHQUAKE ERROR: usp0005p0k with only 0 past earthquakes available.
# Error processing event ID usp0005psp: PAST EARTHQUAKE ERROR: usp0005psp with only 0 past earthquakes available.
# Error processing event ID usp0005pys: PAST EARTHQUAKE ERROR: usp0005pys with only 0 past earthquakes available.
# Error processing event ID usp0005q39: PAST EARTHQUAKE ERROR: usp0005q39 with only 0 past earthquakes available.
# Error processing event ID uw10306313: PAST EARTHQUAKE ERROR: uw10306313 with only 0 past earthquakes available.
# Error processing event ID usp0005qak: PAST EARTHQUAKE ERROR: usp0005qak with only 0 past earthquakes available.
# Error processing event ID usp0005qen: PAST EARTHQUAKE ERROR: usp0005qen with only 0 past earthquakes available.
# Error processing event ID usp0005qx4: PAST EARTHQUAKE ERROR: usp0005qx4 with only 0 past earthquakes available.
# Error processing event ID usp0005r4x: PAST EARTHQUAKE ERROR: usp0005r4x with only 0 past earthquakes available.
# Error processing event ID ak9934vdehk5: PAST EARTHQUAKE ERROR: ak9934vdehk5 with only 0 past earthquakes available.
# Error processing event ID usp0005s12: PAST EARTHQUAKE ERROR: usp0005s12 with only 0 past earthquakes available.
# Error processing event ID usp0005sa0: PAST EARTHQUAKE ERROR: usp0005sa0 with only 0 past earthquakes available.
# Error processing event ID usp0005sm4: PAST EARTHQUAKE ERROR: usp0005sm4 with only 0 past earthquakes available.
# Error processing event ID usp0005sqc: PAST EARTHQUAKE ERROR: usp0005sqc with only 0 past earthquakes available.
# Error processing event ID usp0005std: PAST EARTHQUAKE ERROR: usp0005std with only 1 past earthquakes available.
# Error processing event ID usp0005stj: PAST EARTHQUAKE ERROR: usp0005stj with only 0 past earthquakes available.
# Error processing event ID usp0005stk: PAST EARTHQUAKE ERROR: usp0005stk with only 1 past earthquakes available.
# Error processing event ID usp0005suz: PAST EARTHQUAKE ERROR: usp0005suz with only 0 past earthquakes available.
# Error processing event ID usp0005sx9: PAST EARTHQUAKE ERROR: usp0005sx9 with only 0 past earthquakes available.
# Error processing event ID usp0005sxk: PAST EARTHQUAKE ERROR: usp0005sxk with only 1 past earthquakes available.
# Error processing event ID ci3105173: PAST EARTHQUAKE ERROR: ci3105173 with only 0 past earthquakes available.
# Error processing event ID usp0005t13: PAST EARTHQUAKE ERROR: usp0005t13 with only 0 past earthquakes available.
# Error processing event ID usp0005t53: PAST EARTHQUAKE ERROR: usp0005t53 with only 0 past earthquakes available.
# Error processing event ID usp0005tg0: PAST EARTHQUAKE ERROR: usp0005tg0 with only 0 past earthquakes available.
# Error processing event ID ak9936t0spi3: PAST EARTHQUAKE ERROR: ak9936t0spi3 with only 0 past earthquakes available.
# Error processing event ID usp0005twr: PAST EARTHQUAKE ERROR: usp0005twr with only 0 past earthquakes available.
# Error processing event ID usp0005tyz: PAST EARTHQUAKE ERROR: usp0005tyz with only 0 past earthquakes available.
# Error processing event ID usp0005tze: PAST EARTHQUAKE ERROR: usp0005tze with only 0 past earthquakes available.
# Error processing event ID usp0005u48: PAST EARTHQUAKE ERROR: usp0005u48 with only 0 past earthquakes available.
# Error processing event ID usp0005u5k: PAST EARTHQUAKE ERROR: usp0005u5k with only 2 past earthquakes available.
# Error processing event ID usp0005u7b: PAST EARTHQUAKE ERROR: usp0005u7b with only 0 past earthquakes available.
# Error processing event ID usp0005uen: PAST EARTHQUAKE ERROR: usp0005uen with only 0 past earthquakes available.
# Error processing event ID usp0005ufc: PAST EARTHQUAKE ERROR: usp0005ufc with only 0 past earthquakes available.
# Error processing event ID usp0005uks: PAST EARTHQUAKE ERROR: usp0005uks with only 0 past earthquakes available.
# Error processing event ID usp0005uvc: PAST EARTHQUAKE ERROR: usp0005uvc with only 0 past earthquakes available.
# Error processing event ID usp0005vms: PAST EARTHQUAKE ERROR: usp0005vms with only 0 past earthquakes available.
# Error processing event ID usp0005vnc: PAST EARTHQUAKE ERROR: usp0005vnc with only 0 past earthquakes available.
# Error processing event ID usp0005vre: PAST EARTHQUAKE ERROR: usp0005vre with only 0 past earthquakes available.
# Error processing event ID usp0005vsa: PAST EARTHQUAKE ERROR: usp0005vsa with only 0 past earthquakes available.
# Error processing event ID usp0005vxf: PAST EARTHQUAKE ERROR: usp0005vxf with only 1 past earthquakes available.
# Error processing event ID usp0005vz1: PAST EARTHQUAKE ERROR: usp0005vz1 with only 0 past earthquakes available.
# Error processing event ID usp0005w12: PAST EARTHQUAKE ERROR: usp0005w12 with only 0 past earthquakes available.
# Error processing event ID usp0005w19: PAST EARTHQUAKE ERROR: usp0005w19 with only 0 past earthquakes available.
# Error processing event ID usp0005w1f: PAST EARTHQUAKE ERROR: usp0005w1f with only 0 past earthquakes available.
# Error processing event ID usp0005w1z: PAST EARTHQUAKE ERROR: usp0005w1z with only 3 past earthquakes available.
# Error processing event ID usp0005x4g: PAST EARTHQUAKE ERROR: usp0005x4g with only 0 past earthquakes available.
# Error processing event ID usp0005x5y: PAST EARTHQUAKE ERROR: usp0005x5y with only 0 past earthquakes available.
# Error processing event ID usp0005xts: PAST EARTHQUAKE ERROR: usp0005xts with only 0 past earthquakes available.
# Error processing event ID usp0005xvr: PAST EARTHQUAKE ERROR: usp0005xvr with only 0 past earthquakes available.
# Error processing event ID usp0005y1k: PAST EARTHQUAKE ERROR: usp0005y1k with only 0 past earthquakes available.
# Error processing event ID usp0005y2x: PAST EARTHQUAKE ERROR: usp0005y2x with only 0 past earthquakes available.
# Error processing event ID usp0005y3k: PAST EARTHQUAKE ERROR: usp0005y3k with only 0 past earthquakes available.
# Error processing event ID usp0005y4x: PAST EARTHQUAKE ERROR: usp0005y4x with only 1 past earthquakes available.
# Error processing event ID usp0005y62: PAST EARTHQUAKE ERROR: usp0005y62 with only 1 past earthquakes available.
# Error processing event ID usp0005yc3: PAST EARTHQUAKE ERROR: usp0005yc3 with only 2 past earthquakes available.
# Error processing event ID usp0005ymw: PAST EARTHQUAKE ERROR: usp0005ymw with only 5 past earthquakes available.
# Error processing event ID usp0005yu2: PAST EARTHQUAKE ERROR: usp0005yu2 with only 3 past earthquakes available.
# Error processing event ID usp0005yu3: PAST EARTHQUAKE ERROR: usp0005yu3 with only 0 past earthquakes available.
# Error processing event ID usp0005yv3: PAST EARTHQUAKE ERROR: usp0005yv3 with only 0 past earthquakes available.
# Error processing event ID usp0005yvn: PAST EARTHQUAKE ERROR: usp0005yvn with only 1 past earthquakes available.
# Error processing event ID usp0005ywt: PAST EARTHQUAKE ERROR: usp0005ywt with only 1 past earthquakes available.
# Error processing event ID usp0005yzv: PAST EARTHQUAKE ERROR: usp0005yzv with only 0 past earthquakes available.
# Error processing event ID usp0005zj7: PAST EARTHQUAKE ERROR: usp0005zj7 with only 1 past earthquakes available.
# Error processing event ID usp0005znq: PAST EARTHQUAKE ERROR: usp0005znq with only 1 past earthquakes available.
# Error processing event ID usp0005zpf: PAST EARTHQUAKE ERROR: usp0005zpf with only 1 past earthquakes available.
# Error processing event ID usp0005zqw: PAST EARTHQUAKE ERROR: usp0005zqw with only 2 past earthquakes available.
# Error processing event ID usp000602w: PAST EARTHQUAKE ERROR: usp000602w with only 3 past earthquakes available.
# Error processing event ID usp000602z: PAST EARTHQUAKE ERROR: usp000602z with only 5 past earthquakes available.
# Error processing event ID usp0006030: PAST EARTHQUAKE ERROR: usp0006030 with only 1 past earthquakes available.
# Error processing event ID usp0006048: PAST EARTHQUAKE ERROR: usp0006048 with only 1 past earthquakes available.
# Error processing event ID usp000605u: PAST EARTHQUAKE ERROR: usp000605u with only 1 past earthquakes available.
# Error processing event ID usp000605z: PAST EARTHQUAKE ERROR: usp000605z with only 0 past earthquakes available.
# Error processing event ID usp000606e: PAST EARTHQUAKE ERROR: usp000606e with only 0 past earthquakes available.
# Error processing event ID usp000609w: PAST EARTHQUAKE ERROR: usp000609w with only 1 past earthquakes available.
# Error processing event ID usp00060a9: PAST EARTHQUAKE ERROR: usp00060a9 with only 5 past earthquakes available.
# Error processing event ID usp00060ee: PAST EARTHQUAKE ERROR: usp00060ee with only 0 past earthquakes available.
# Error processing event ID usp00060jk: PAST EARTHQUAKE ERROR: usp00060jk with only 4 past earthquakes available.
# Error processing event ID usp00060ky: PAST EARTHQUAKE ERROR: usp00060ky with only 7 past earthquakes available.
# Error processing event ID usp00060m0: PAST EARTHQUAKE ERROR: usp00060m0 with only 1 past earthquakes available.
# Error processing event ID usp00060mr: PAST EARTHQUAKE ERROR: usp00060mr with only 2 past earthquakes available.
# Error processing event ID uw10313718: PAST EARTHQUAKE ERROR: uw10313718 with only 1 past earthquakes available.
# Error processing event ID uw10313838: PAST EARTHQUAKE ERROR: uw10313838 with only 8 past earthquakes available.
# Error processing event ID usp0006122: PAST EARTHQUAKE ERROR: usp0006122 with only 0 past earthquakes available.
# Error processing event ID usp000612p: PAST EARTHQUAKE ERROR: usp000612p with only 6 past earthquakes available.
# Error processing event ID usp000613s: PAST EARTHQUAKE ERROR: usp000613s with only 0 past earthquakes available.
# Error processing event ID usp000619m: PAST EARTHQUAKE ERROR: usp000619m with only 0 past earthquakes available.
# Error processing event ID usp00061f2: PAST EARTHQUAKE ERROR: usp00061f2 with only 0 past earthquakes available.
# Error processing event ID usp00061pb: PAST EARTHQUAKE ERROR: usp00061pb with only 0 past earthquakes available.
# Error processing event ID usp00061tu: PAST EARTHQUAKE ERROR: usp00061tu with only 0 past earthquakes available.
# Error processing event ID usp00061vw: PAST EARTHQUAKE ERROR: usp00061vw with only 0 past earthquakes available.
# Error processing event ID usp0006239: PAST EARTHQUAKE ERROR: usp0006239 with only 0 past earthquakes available.
# Error processing event ID usp00062jf: PAST EARTHQUAKE ERROR: usp00062jf with only 0 past earthquakes available.
# Error processing event ID usp00062jn: PAST EARTHQUAKE ERROR: usp00062jn with only 1 past earthquakes available.
# Error processing event ID usp00062vk: PAST EARTHQUAKE ERROR: usp00062vk with only 0 past earthquakes available.
# Error processing event ID usp00062x6: PAST EARTHQUAKE ERROR: usp00062x6 with only 0 past earthquakes available.
# Error processing event ID usp00063gg: PAST EARTHQUAKE ERROR: usp00063gg with only 0 past earthquakes available.
# Error processing event ID usp00063j0: PAST EARTHQUAKE ERROR: usp00063j0 with only 1 past earthquakes available.
# Error processing event ID usp00063kg: PAST EARTHQUAKE ERROR: usp00063kg with only 0 past earthquakes available.
# Error processing event ID usp00063mg: PAST EARTHQUAKE ERROR: usp00063mg with only 0 past earthquakes available.
# Error processing event ID usp00063mj: PAST EARTHQUAKE ERROR: usp00063mj with only 0 past earthquakes available.
# Error processing event ID usp00063u1: PAST EARTHQUAKE ERROR: usp00063u1 with only 0 past earthquakes available.
# Error processing event ID usp00063vy: PAST EARTHQUAKE ERROR: usp00063vy with only 0 past earthquakes available.
# Error processing event ID usp00063w1: PAST EARTHQUAKE ERROR: usp00063w1 with only 0 past earthquakes available.
# Error processing event ID ak993ew5kxsm: PAST EARTHQUAKE ERROR: ak993ew5kxsm with only 5 past earthquakes available.
# Error processing event ID usp000642p: PAST EARTHQUAKE ERROR: usp000642p with only 0 past earthquakes available.
# Error processing event ID usp00064a8: PAST EARTHQUAKE ERROR: usp00064a8 with only 0 past earthquakes available.
# Error processing event ID usp00064ed: PAST EARTHQUAKE ERROR: usp00064ed with only 2 past earthquakes available.
# Error processing event ID usp00064ke: PAST EARTHQUAKE ERROR: usp00064ke with only 2 past earthquakes available.
# Error processing event ID usp00064xw: PAST EARTHQUAKE ERROR: usp00064xw with only 0 past earthquakes available.
# Error processing event ID usp0006511: PAST EARTHQUAKE ERROR: usp0006511 with only 1 past earthquakes available.
# Error processing event ID usp000657g: PAST EARTHQUAKE ERROR: usp000657g with only 0 past earthquakes available.
# Error processing event ID usp00065qw: PAST EARTHQUAKE ERROR: usp00065qw with only 1 past earthquakes available.
# Error processing event ID usp00065ye: PAST EARTHQUAKE ERROR: usp00065ye with only 0 past earthquakes available.
# Error processing event ID usp000661b: PAST EARTHQUAKE ERROR: usp000661b with only 0 past earthquakes available.
# Error processing event ID usp000661q: PAST EARTHQUAKE ERROR: usp000661q with only 0 past earthquakes available.
# Error processing event ID usp0006649: PAST EARTHQUAKE ERROR: usp0006649 with only 1 past earthquakes available.
# Error processing event ID ci3144585: PAST EARTHQUAKE ERROR: ci3144585 with only 0 past earthquakes available.
# Error processing event ID ci3149646: PAST EARTHQUAKE ERROR: ci3149646 with only 2 past earthquakes available.
# Error processing event ID usp0006714: PAST EARTHQUAKE ERROR: usp0006714 with only 1 past earthquakes available.
# Error processing event ID usp00067cd: PAST EARTHQUAKE ERROR: usp00067cd with only 0 past earthquakes available.
# Error processing event ID usp00067fr: PAST EARTHQUAKE ERROR: usp00067fr with only 0 past earthquakes available.
# Error processing event ID usp00067xb: PAST EARTHQUAKE ERROR: usp00067xb with only 1 past earthquakes available.
# Error processing event ID usp000683x: PAST EARTHQUAKE ERROR: usp000683x with only 0 past earthquakes available.
# Error processing event ID usp00068da: PAST EARTHQUAKE ERROR: usp00068da with only 0 past earthquakes available.
# Error processing event ID usp00068gs: PAST EARTHQUAKE ERROR: usp00068gs with only 2 past earthquakes available.
# Error processing event ID usp00068ng: PAST EARTHQUAKE ERROR: usp00068ng with only 0 past earthquakes available.
# Error processing event ID usp00068t7: PAST EARTHQUAKE ERROR: usp00068t7 with only 2 past earthquakes available.
# Error processing event ID usp00068ww: PAST EARTHQUAKE ERROR: usp00068ww with only 0 past earthquakes available.
# Error processing event ID usp00068xb: PAST EARTHQUAKE ERROR: usp00068xb with only 0 past earthquakes available.
# Error processing event ID usp000693g: PAST EARTHQUAKE ERROR: usp000693g with only 1 past earthquakes available.
# Error processing event ID usp00069c0: PAST EARTHQUAKE ERROR: usp00069c0 with only 1 past earthquakes available.
# Error processing event ID usp00069hh: PAST EARTHQUAKE ERROR: usp00069hh with only 2 past earthquakes available.
# Error processing event ID usp00069mn: PAST EARTHQUAKE ERROR: usp00069mn with only 0 past earthquakes available.
# Error processing event ID usp00069mp: PAST EARTHQUAKE ERROR: usp00069mp with only 0 past earthquakes available.
# Error processing event ID usp00069qa: PAST EARTHQUAKE ERROR: usp00069qa with only 0 past earthquakes available.
# Error processing event ID usp00069qj: PAST EARTHQUAKE ERROR: usp00069qj with only 0 past earthquakes available.
# Error processing event ID usp00069re: PAST EARTHQUAKE ERROR: usp00069re with only 0 past earthquakes available.
# Error processing event ID usp00069ts: PAST EARTHQUAKE ERROR: usp00069ts with only 1 past earthquakes available.
# Error processing event ID usp00069un: PAST EARTHQUAKE ERROR: usp00069un with only 0 past earthquakes available.
# Error processing event ID usp00069w5: PAST EARTHQUAKE ERROR: usp00069w5 with only 1 past earthquakes available.
# Error processing event ID usp0006a79: PAST EARTHQUAKE ERROR: usp0006a79 with only 0 past earthquakes available.
# Error processing event ID usp0006acz: PAST EARTHQUAKE ERROR: usp0006acz with only 0 past earthquakes available.
# Error processing event ID usp0006ap2: PAST EARTHQUAKE ERROR: usp0006ap2 with only 3 past earthquakes available.
# Error processing event ID usp0006aqa: PAST EARTHQUAKE ERROR: usp0006aqa with only 1 past earthquakes available.
# Error processing event ID usp0006at4: PAST EARTHQUAKE ERROR: usp0006at4 with only 0 past earthquakes available.
# Error processing event ID usp0006ax2: PAST EARTHQUAKE ERROR: usp0006ax2 with only 0 past earthquakes available.
# Error processing event ID usp0006axj: PAST EARTHQUAKE ERROR: usp0006axj with only 0 past earthquakes available.
# Error processing event ID usp0006b0k: PAST EARTHQUAKE ERROR: usp0006b0k with only 0 past earthquakes available.
# Error processing event ID usp0006b57: PAST EARTHQUAKE ERROR: usp0006b57 with only 1 past earthquakes available.
# Error processing event ID usp0006br0: PAST EARTHQUAKE ERROR: usp0006br0 with only 0 past earthquakes available.
# Error processing event ID usp0006bty: PAST EARTHQUAKE ERROR: usp0006bty with only 0 past earthquakes available.
# Error processing event ID usp0006bwg: PAST EARTHQUAKE ERROR: usp0006bwg with only 0 past earthquakes available.
# Error processing event ID usp0006byz: PAST EARTHQUAKE ERROR: usp0006byz with only 1 past earthquakes available.
# Error processing event ID usp0006c7g: PAST EARTHQUAKE ERROR: usp0006c7g with only 1 past earthquakes available.
# Error processing event ID usp0006cbk: PAST EARTHQUAKE ERROR: usp0006cbk with only 0 past earthquakes available.
# Error processing event ID usp0006ccd: PAST EARTHQUAKE ERROR: usp0006ccd with only 2 past earthquakes available.
# Error processing event ID usp0006ce8: PAST EARTHQUAKE ERROR: usp0006ce8 with only 0 past earthquakes available.
# Error processing event ID usp0006cgs: PAST EARTHQUAKE ERROR: usp0006cgs with only 0 past earthquakes available.
# Error processing event ID usp0006cr7: PAST EARTHQUAKE ERROR: usp0006cr7 with only 1 past earthquakes available.
# Error processing event ID usp0006cuz: PAST EARTHQUAKE ERROR: usp0006cuz with only 0 past earthquakes available.
# Error processing event ID usp0006cyv: PAST EARTHQUAKE ERROR: usp0006cyv with only 0 past earthquakes available.
# Error processing event ID usp0006cyx: PAST EARTHQUAKE ERROR: usp0006cyx with only 1 past earthquakes available.
# Error processing event ID usp0006cz0: PAST EARTHQUAKE ERROR: usp0006cz0 with only 2 past earthquakes available.
# Error processing event ID usp0006czh: PAST EARTHQUAKE ERROR: usp0006czh with only 3 past earthquakes available.
# Error processing event ID usp0006d02: PAST EARTHQUAKE ERROR: usp0006d02 with only 3 past earthquakes available.
# Error processing event ID usp0006d0c: PAST EARTHQUAKE ERROR: usp0006d0c with only 0 past earthquakes available.
# Error processing event ID usp0006d1u: PAST EARTHQUAKE ERROR: usp0006d1u with only 0 past earthquakes available.
# Error processing event ID usp0006d2w: PAST EARTHQUAKE ERROR: usp0006d2w with only 1 past earthquakes available.
# Error processing event ID usp0006d6c: PAST EARTHQUAKE ERROR: usp0006d6c with only 0 past earthquakes available.
# Error processing event ID usp0006dey: PAST EARTHQUAKE ERROR: usp0006dey with only 0 past earthquakes available.
# Error processing event ID usp0006drf: PAST EARTHQUAKE ERROR: usp0006drf with only 1 past earthquakes available.
# Error processing event ID usp0006du9: PAST EARTHQUAKE ERROR: usp0006du9 with only 0 past earthquakes available.
# Error processing event ID usp0006dz3: PAST EARTHQUAKE ERROR: usp0006dz3 with only 0 past earthquakes available.
# Error processing event ID usp0006e0f: PAST EARTHQUAKE ERROR: usp0006e0f with only 0 past earthquakes available.
# Error processing event ID usp0006e2g: PAST EARTHQUAKE ERROR: usp0006e2g with only 0 past earthquakes available.
# Error processing event ID usp0006eyz: PAST EARTHQUAKE ERROR: usp0006eyz with only 0 past earthquakes available.
# Error processing event ID usp0006f67: PAST EARTHQUAKE ERROR: usp0006f67 with only 0 past earthquakes available.
# Error processing event ID usp0006f6f: PAST EARTHQUAKE ERROR: usp0006f6f with only 0 past earthquakes available.
# Error processing event ID usp0006f70: PAST EARTHQUAKE ERROR: usp0006f70 with only 0 past earthquakes available.
# Error processing event ID usp0006fhs: PAST EARTHQUAKE ERROR: usp0006fhs with only 0 past earthquakes available.
# Error processing event ID usp0006fpa: PAST EARTHQUAKE ERROR: usp0006fpa with only 0 past earthquakes available.
# Error processing event ID usp0006fyv: PAST EARTHQUAKE ERROR: usp0006fyv with only 0 past earthquakes available.
# Error processing event ID usp0006fyx: PAST EARTHQUAKE ERROR: usp0006fyx with only 0 past earthquakes available.
# Error processing event ID usp0006g8c: PAST EARTHQUAKE ERROR: usp0006g8c with only 0 past earthquakes available.
# Error processing event ID usp0006gey: PAST EARTHQUAKE ERROR: usp0006gey with only 1 past earthquakes available.
# Error processing event ID usp0006gje: PAST EARTHQUAKE ERROR: usp0006gje with only 0 past earthquakes available.
# Error processing event ID usp0006gk3: PAST EARTHQUAKE ERROR: usp0006gk3 with only 0 past earthquakes available.
# Error processing event ID usp0006gkn: PAST EARTHQUAKE ERROR: usp0006gkn with only 0 past earthquakes available.
# Error processing event ID usp0006gxh: PAST EARTHQUAKE ERROR: usp0006gxh with only 0 past earthquakes available.
# Error processing event ID usp0006gxk: PAST EARTHQUAKE ERROR: usp0006gxk with only 2 past earthquakes available.
# Error processing event ID usp0006gy7: PAST EARTHQUAKE ERROR: usp0006gy7 with only 0 past earthquakes available.
# Error processing event ID usp0006h01: PAST EARTHQUAKE ERROR: usp0006h01 with only 0 past earthquakes available.
# Error processing event ID usp0006h0d: PAST EARTHQUAKE ERROR: usp0006h0d with only 0 past earthquakes available.
# Error processing event ID usp0006h3d: PAST EARTHQUAKE ERROR: usp0006h3d with only 1 past earthquakes available.
# Error processing event ID usp0006h3e: PAST EARTHQUAKE ERROR: usp0006h3e with only 1 past earthquakes available.
# Error processing event ID usp0006h3f: PAST EARTHQUAKE ERROR: usp0006h3f with only 0 past earthquakes available.
# Error processing event ID usp0006h70: PAST EARTHQUAKE ERROR: usp0006h70 with only 3 past earthquakes available.
# Error processing event ID usp0006h73: PAST EARTHQUAKE ERROR: usp0006h73 with only 0 past earthquakes available.
# Error processing event ID usp0006h9t: PAST EARTHQUAKE ERROR: usp0006h9t with only 1 past earthquakes available.
# Error processing event ID usp0006hm2: PAST EARTHQUAKE ERROR: usp0006hm2 with only 0 past earthquakes available.
# Error processing event ID usp0006hm5: PAST EARTHQUAKE ERROR: usp0006hm5 with only 3 past earthquakes available.
# Error processing event ID usp0006hpj: PAST EARTHQUAKE ERROR: usp0006hpj with only 7 past earthquakes available.
# Error processing event ID usp0006hr0: PAST EARTHQUAKE ERROR: usp0006hr0 with only 1 past earthquakes available.
# Error processing event ID usp0006hsx: PAST EARTHQUAKE ERROR: usp0006hsx with only 2 past earthquakes available.
# Error processing event ID usp0006j05: PAST EARTHQUAKE ERROR: usp0006j05 with only 0 past earthquakes available.
# Error processing event ID usp0006j6f: PAST EARTHQUAKE ERROR: usp0006j6f with only 0 past earthquakes available.
# Error processing event ID usp0006j9b: PAST EARTHQUAKE ERROR: usp0006j9b with only 3 past earthquakes available.
# Error processing event ID usp0006jc3: PAST EARTHQUAKE ERROR: usp0006jc3 with only 0 past earthquakes available.
# Error processing event ID usp0006jct: PAST EARTHQUAKE ERROR: usp0006jct with only 1 past earthquakes available.
# Error processing event ID usp0006jhk: PAST EARTHQUAKE ERROR: usp0006jhk with only 0 past earthquakes available.
# Error processing event ID usp0006jrd: PAST EARTHQUAKE ERROR: usp0006jrd with only 2 past earthquakes available.
# Error processing event ID usp0006k4f: PAST EARTHQUAKE ERROR: usp0006k4f with only 1 past earthquakes available.
# Error processing event ID usp0006kdp: PAST EARTHQUAKE ERROR: usp0006kdp with only 1 past earthquakes available.
# Error processing event ID usp0006kdr: PAST EARTHQUAKE ERROR: usp0006kdr with only 0 past earthquakes available.
# Error processing event ID usp0006kds: PAST EARTHQUAKE ERROR: usp0006kds with only 1 past earthquakes available.
# Error processing event ID usp0006kdt: PAST EARTHQUAKE ERROR: usp0006kdt with only 0 past earthquakes available.
# Error processing event ID usp0006ke7: PAST EARTHQUAKE ERROR: usp0006ke7 with only 2 past earthquakes available.
# Error processing event ID usp0006keg: PAST EARTHQUAKE ERROR: usp0006keg with only 0 past earthquakes available.
# Error processing event ID usp0006keh: PAST EARTHQUAKE ERROR: usp0006keh with only 5 past earthquakes available.
# Error processing event ID usp0006ker: PAST EARTHQUAKE ERROR: usp0006ker with only 3 past earthquakes available.
# Error processing event ID usp0006ket: PAST EARTHQUAKE ERROR: usp0006ket with only 2 past earthquakes available.
# Error processing event ID usp0006kfs: PAST EARTHQUAKE ERROR: usp0006kfs with only 3 past earthquakes available.
# Error processing event ID usp0006kg4: PAST EARTHQUAKE ERROR: usp0006kg4 with only 1 past earthquakes available.
# Error processing event ID usp0006kg9: PAST EARTHQUAKE ERROR: usp0006kg9 with only 0 past earthquakes available.
# Error processing event ID usp0006kgv: PAST EARTHQUAKE ERROR: usp0006kgv with only 5 past earthquakes available.
# Error processing event ID usp0006khs: PAST EARTHQUAKE ERROR: usp0006khs with only 1 past earthquakes available.
# Error processing event ID usp0006kja: PAST EARTHQUAKE ERROR: usp0006kja with only 1 past earthquakes available.
# Error processing event ID usp0006kjt: PAST EARTHQUAKE ERROR: usp0006kjt with only 8 past earthquakes available.
# Error processing event ID usp0006kkn: PAST EARTHQUAKE ERROR: usp0006kkn with only 5 past earthquakes available.
# Error processing event ID usp0006kkp: PAST EARTHQUAKE ERROR: usp0006kkp with only 5 past earthquakes available.
# Error processing event ID usp0006kmm: PAST EARTHQUAKE ERROR: usp0006kmm with only 7 past earthquakes available.
# Error processing event ID usp0006kmp: PAST EARTHQUAKE ERROR: usp0006kmp with only 3 past earthquakes available.
# Error processing event ID usp0006knh: PAST EARTHQUAKE ERROR: usp0006knh with only 4 past earthquakes available.
# Error processing event ID usp0006kq9: PAST EARTHQUAKE ERROR: usp0006kq9 with only 7 past earthquakes available.
# Error processing event ID usp0006kqk: PAST EARTHQUAKE ERROR: usp0006kqk with only 1 past earthquakes available.
# Error processing event ID usp0006ku9: PAST EARTHQUAKE ERROR: usp0006ku9 with only 5 past earthquakes available.
# Error processing event ID usp0006kuc: PAST EARTHQUAKE ERROR: usp0006kuc with only 10 past earthquakes available.
# Error processing event ID usp0006kuh: PAST EARTHQUAKE ERROR: usp0006kuh with only 3 past earthquakes available.
# Error processing event ID usp0006kuv: PAST EARTHQUAKE ERROR: usp0006kuv with only 4 past earthquakes available.
# Error processing event ID usp0006kv4: PAST EARTHQUAKE ERROR: usp0006kv4 with only 8 past earthquakes available.
# Error processing event ID usp0006kxp: PAST EARTHQUAKE ERROR: usp0006kxp with only 0 past earthquakes available.
# Error processing event ID usp0006kzz: PAST EARTHQUAKE ERROR: usp0006kzz with only 0 past earthquakes available.
# Error processing event ID usp0006m04: PAST EARTHQUAKE ERROR: usp0006m04 with only 3 past earthquakes available.
# Error processing event ID usp0006m6j: PAST EARTHQUAKE ERROR: usp0006m6j with only 0 past earthquakes available.
# Error processing event ID usp0006mas: PAST EARTHQUAKE ERROR: usp0006mas with only 2 past earthquakes available.
# Error processing event ID usp0006mta: PAST EARTHQUAKE ERROR: usp0006mta with only 0 past earthquakes available.
# Error processing event ID usp0006mu7: PAST EARTHQUAKE ERROR: usp0006mu7 with only 0 past earthquakes available.
# Error processing event ID usp0006mv6: PAST EARTHQUAKE ERROR: usp0006mv6 with only 0 past earthquakes available.
# Error processing event ID usp0006mz9: PAST EARTHQUAKE ERROR: usp0006mz9 with only 0 past earthquakes available.
# Error processing event ID usp0006n5m: PAST EARTHQUAKE ERROR: usp0006n5m with only 0 past earthquakes available.
# Error processing event ID usp0006n6k: PAST EARTHQUAKE ERROR: usp0006n6k with only 2 past earthquakes available.
# Error processing event ID usp0006nbf: PAST EARTHQUAKE ERROR: usp0006nbf with only 3 past earthquakes available.
# Error processing event ID usp0006nn2: PAST EARTHQUAKE ERROR: usp0006nn2 with only 0 past earthquakes available.
# Error processing event ID usp0006nnr: PAST EARTHQUAKE ERROR: usp0006nnr with only 1 past earthquakes available.
# Error processing event ID usp0006npu: PAST EARTHQUAKE ERROR: usp0006npu with only 0 past earthquakes available.
# Error processing event ID usp0006nvu: PAST EARTHQUAKE ERROR: usp0006nvu with only 16 past earthquakes available.
# Error processing event ID usp0006p20: PAST EARTHQUAKE ERROR: usp0006p20 with only 11 past earthquakes available.
# Error processing event ID usp0006pwk: PAST EARTHQUAKE ERROR: usp0006pwk with only 0 past earthquakes available.
# Error processing event ID usp0006q00: PAST EARTHQUAKE ERROR: usp0006q00 with only 0 past earthquakes available.
# Error processing event ID usp0006qgm: PAST EARTHQUAKE ERROR: usp0006qgm with only 0 past earthquakes available.
# Error processing event ID usp0006qgq: PAST EARTHQUAKE ERROR: usp0006qgq with only 0 past earthquakes available.
# Error processing event ID usp0006qh3: PAST EARTHQUAKE ERROR: usp0006qh3 with only 0 past earthquakes available.
# Error processing event ID usp0006qh4: PAST EARTHQUAKE ERROR: usp0006qh4 with only 2 past earthquakes available.
# Error processing event ID usp0006qh8: PAST EARTHQUAKE ERROR: usp0006qh8 with only 0 past earthquakes available.
# Error processing event ID usp0006qha: PAST EARTHQUAKE ERROR: usp0006qha with only 0 past earthquakes available.
# Error processing event ID usp0006qhj: PAST EARTHQUAKE ERROR: usp0006qhj with only 1 past earthquakes available.
# Error processing event ID usp0006qj0: PAST EARTHQUAKE ERROR: usp0006qj0 with only 2 past earthquakes available.
# Error processing event ID usp0006qja: PAST EARTHQUAKE ERROR: usp0006qja with only 1 past earthquakes available.
# Error processing event ID usp0006qjm: PAST EARTHQUAKE ERROR: usp0006qjm with only 2 past earthquakes available.
# Error processing event ID usp0006qjq: PAST EARTHQUAKE ERROR: usp0006qjq with only 4 past earthquakes available.
# Error processing event ID usp0006qkh: PAST EARTHQUAKE ERROR: usp0006qkh with only 0 past earthquakes available.
# Error processing event ID usp0006qmz: PAST EARTHQUAKE ERROR: usp0006qmz with only 0 past earthquakes available.
# Error processing event ID usp0006qny: PAST EARTHQUAKE ERROR: usp0006qny with only 2 past earthquakes available.
# Error processing event ID usp0006qpv: PAST EARTHQUAKE ERROR: usp0006qpv with only 3 past earthquakes available.
# Error processing event ID usp0006qyu: PAST EARTHQUAKE ERROR: usp0006qyu with only 2 past earthquakes available.
# Error processing event ID usp0006qyz: PAST EARTHQUAKE ERROR: usp0006qyz with only 0 past earthquakes available.
# Error processing event ID usp0006qz9: PAST EARTHQUAKE ERROR: usp0006qz9 with only 3 past earthquakes available.
# Error processing event ID usp0006r3k: PAST EARTHQUAKE ERROR: usp0006r3k with only 0 past earthquakes available.
# Error processing event ID usp0006r4v: PAST EARTHQUAKE ERROR: usp0006r4v with only 0 past earthquakes available.
# Error processing event ID usp0006r6k: PAST EARTHQUAKE ERROR: usp0006r6k with only 3 past earthquakes available.
# Error processing event ID usp0006r7u: PAST EARTHQUAKE ERROR: usp0006r7u with only 3 past earthquakes available.
# Error processing event ID usp0006r8q: PAST EARTHQUAKE ERROR: usp0006r8q with only 9 past earthquakes available.
# Error processing event ID usp0006rbr: PAST EARTHQUAKE ERROR: usp0006rbr with only 0 past earthquakes available.
# Error processing event ID usp0006rek: PAST EARTHQUAKE ERROR: usp0006rek with only 1 past earthquakes available.
# Error processing event ID usp0006req: PAST EARTHQUAKE ERROR: usp0006req with only 3 past earthquakes available.
# Error processing event ID usp0006rew: PAST EARTHQUAKE ERROR: usp0006rew with only 0 past earthquakes available.
# Error processing event ID usp0006rjy: PAST EARTHQUAKE ERROR: usp0006rjy with only 6 past earthquakes available.
# Error processing event ID usp0006rmq: PAST EARTHQUAKE ERROR: usp0006rmq with only 15 past earthquakes available.
# Error processing event ID usp0006rn5: PAST EARTHQUAKE ERROR: usp0006rn5 with only 0 past earthquakes available.
# Error processing event ID usp0006rpc: PAST EARTHQUAKE ERROR: usp0006rpc with only 9 past earthquakes available.
# Error processing event ID usp0006rxu: PAST EARTHQUAKE ERROR: usp0006rxu with only 6 past earthquakes available.
# Error processing event ID usp0006ryw: PAST EARTHQUAKE ERROR: usp0006ryw with only 0 past earthquakes available.
# Error processing event ID usp0006s0f: PAST EARTHQUAKE ERROR: usp0006s0f with only 3 past earthquakes available.
# Error processing event ID usp0006s1n: PAST EARTHQUAKE ERROR: usp0006s1n with only 0 past earthquakes available.
# Error processing event ID usp0006sg0: PAST EARTHQUAKE ERROR: usp0006sg0 with only 0 past earthquakes available.
# Error processing event ID usp0006ss3: PAST EARTHQUAKE ERROR: usp0006ss3 with only 0 past earthquakes available.
# Error processing event ID ak9951zg3gik: PAST EARTHQUAKE ERROR: ak9951zg3gik with only 3 past earthquakes available.
# Error processing event ID usp0006syb: PAST EARTHQUAKE ERROR: usp0006syb with only 0 past earthquakes available.
# Error processing event ID usp0006syp: PAST EARTHQUAKE ERROR: usp0006syp with only 8 past earthquakes available.
# Error processing event ID usp0006t5a: PAST EARTHQUAKE ERROR: usp0006t5a with only 0 past earthquakes available.
# Error processing event ID nc30068187: PAST EARTHQUAKE ERROR: nc30068187 with only 2 past earthquakes available.
# Error processing event ID usp0006t68: PAST EARTHQUAKE ERROR: usp0006t68 with only 9 past earthquakes available.
# Error processing event ID usp0006t9t: PAST EARTHQUAKE ERROR: usp0006t9t with only 1 past earthquakes available.
# Error processing event ID usp0006tcw: PAST EARTHQUAKE ERROR: usp0006tcw with only 3 past earthquakes available.
# Error processing event ID usp0006tcx: PAST EARTHQUAKE ERROR: usp0006tcx with only 1 past earthquakes available.
# Error processing event ID usp0006tcy: PAST EARTHQUAKE ERROR: usp0006tcy with only 4 past earthquakes available.
# Error processing event ID usp0006u0a: PAST EARTHQUAKE ERROR: usp0006u0a with only 0 past earthquakes available.
# Error processing event ID usp0006u2d: PAST EARTHQUAKE ERROR: usp0006u2d with only 5 past earthquakes available.
# Error processing event ID usp0006u6k: PAST EARTHQUAKE ERROR: usp0006u6k with only 0 past earthquakes available.
# Error processing event ID usp0006urp: PAST EARTHQUAKE ERROR: usp0006urp with only 1 past earthquakes available.
# Error processing event ID usp0006uya: PAST EARTHQUAKE ERROR: usp0006uya with only 0 past earthquakes available.
# Error processing event ID usp0006uz0: PAST EARTHQUAKE ERROR: usp0006uz0 with only 0 past earthquakes available.
# Error processing event ID usp0006uzz: PAST EARTHQUAKE ERROR: usp0006uzz with only 1 past earthquakes available.
# Error processing event ID usp0006v33: PAST EARTHQUAKE ERROR: usp0006v33 with only 1 past earthquakes available.
# Error processing event ID usp0006vch: PAST EARTHQUAKE ERROR: usp0006vch with only 0 past earthquakes available.
# Error processing event ID usp0006vck: PAST EARTHQUAKE ERROR: usp0006vck with only 0 past earthquakes available.
# Error processing event ID usp0006vmm: PAST EARTHQUAKE ERROR: usp0006vmm with only 0 past earthquakes available.
# Error processing event ID usp0006vua: PAST EARTHQUAKE ERROR: usp0006vua with only 1 past earthquakes available.
# Error processing event ID usp0006vun: PAST EARTHQUAKE ERROR: usp0006vun with only 1 past earthquakes available.
# Error processing event ID usp0006vwa: PAST EARTHQUAKE ERROR: usp0006vwa with only 8 past earthquakes available.
# Error processing event ID usp0006vz3: PAST EARTHQUAKE ERROR: usp0006vz3 with only 3 past earthquakes available.
# Error processing event ID usp0006vz4: PAST EARTHQUAKE ERROR: usp0006vz4 with only 1 past earthquakes available.
# Error processing event ID usp0006vz8: PAST EARTHQUAKE ERROR: usp0006vz8 with only 2 past earthquakes available.
# Error processing event ID usp0006vz9: PAST EARTHQUAKE ERROR: usp0006vz9 with only 2 past earthquakes available.
# Error processing event ID usp0006w0m: PAST EARTHQUAKE ERROR: usp0006w0m with only 2 past earthquakes available.
# Error processing event ID usp0006w47: PAST EARTHQUAKE ERROR: usp0006w47 with only 9 past earthquakes available.
# Error processing event ID usp0006w5n: PAST EARTHQUAKE ERROR: usp0006w5n with only 1 past earthquakes available.
# Error processing event ID usp0006w5w: PAST EARTHQUAKE ERROR: usp0006w5w with only 1 past earthquakes available.
# Error processing event ID usp0006w91: PAST EARTHQUAKE ERROR: usp0006w91 with only 6 past earthquakes available.
# Error processing event ID usp0006w9t: PAST EARTHQUAKE ERROR: usp0006w9t with only 2 past earthquakes available.
# Error processing event ID usp0006way: PAST EARTHQUAKE ERROR: usp0006way with only 9 past earthquakes available.
# Error processing event ID usp0006wgc: PAST EARTHQUAKE ERROR: usp0006wgc with only 10 past earthquakes available.
# Error processing event ID usp0006wge: PAST EARTHQUAKE ERROR: usp0006wge with only 10 past earthquakes available.
# Error processing event ID usp0006whs: PAST EARTHQUAKE ERROR: usp0006whs with only 3 past earthquakes available.
# Error processing event ID usp0006ww5: PAST EARTHQUAKE ERROR: usp0006ww5 with only 3 past earthquakes available.
# Error processing event ID usp0006wwb: PAST EARTHQUAKE ERROR: usp0006wwb with only 3 past earthquakes available.
# Error processing event ID usp0006x2z: PAST EARTHQUAKE ERROR: usp0006x2z with only 8 past earthquakes available.
# Error processing event ID usp0006x30: PAST EARTHQUAKE ERROR: usp0006x30 with only 1 past earthquakes available.
# Error processing event ID usp0006x32: PAST EARTHQUAKE ERROR: usp0006x32 with only 3 past earthquakes available.
# Error processing event ID usp0006xgm: PAST EARTHQUAKE ERROR: usp0006xgm with only 14 past earthquakes available.
# Error processing event ID usp0006xkz: PAST EARTHQUAKE ERROR: usp0006xkz with only 1 past earthquakes available.
# Error processing event ID usp0006xn9: PAST EARTHQUAKE ERROR: usp0006xn9 with only 3 past earthquakes available.
# Error processing event ID usp0006xts: PAST EARTHQUAKE ERROR: usp0006xts with only 1 past earthquakes available.
# Error processing event ID usp0006xw8: PAST EARTHQUAKE ERROR: usp0006xw8 with only 0 past earthquakes available.
# Error processing event ID ak9956mby779: PAST EARTHQUAKE ERROR: ak9956mby779 with only 1 past earthquakes available.
# Error processing event ID usp0006xz7: PAST EARTHQUAKE ERROR: usp0006xz7 with only 12 past earthquakes available.
# Error processing event ID usp0006y0c: PAST EARTHQUAKE ERROR: usp0006y0c with only 7 past earthquakes available.
# Error processing event ID usp0006y50: PAST EARTHQUAKE ERROR: usp0006y50 with only 0 past earthquakes available.
# Error processing event ID usp0006y5m: PAST EARTHQUAKE ERROR: usp0006y5m with only 0 past earthquakes available.
# Error processing event ID usp0006y8w: PAST EARTHQUAKE ERROR: usp0006y8w with only 1 past earthquakes available.
# Error processing event ID usp0006yd5: PAST EARTHQUAKE ERROR: usp0006yd5 with only 1 past earthquakes available.
# Error processing event ID usp0006ymm: PAST EARTHQUAKE ERROR: usp0006ymm with only 1 past earthquakes available.
# Error processing event ID usp0006yy3: PAST EARTHQUAKE ERROR: usp0006yy3 with only 19 past earthquakes available.
# Error processing event ID usp0006z1y: PAST EARTHQUAKE ERROR: usp0006z1y with only 0 past earthquakes available.
# Error processing event ID usp0006z26: PAST EARTHQUAKE ERROR: usp0006z26 with only 1 past earthquakes available.
# Error processing event ID usp0006z27: PAST EARTHQUAKE ERROR: usp0006z27 with only 2 past earthquakes available.
# Error processing event ID usp0006znz: PAST EARTHQUAKE ERROR: usp0006znz with only 0 past earthquakes available.
# Error processing event ID usp0006zsj: PAST EARTHQUAKE ERROR: usp0006zsj with only 0 past earthquakes available.
# Error processing event ID usp0006zw0: PAST EARTHQUAKE ERROR: usp0006zw0 with only 0 past earthquakes available.
# Error processing event ID usp0006zwy: PAST EARTHQUAKE ERROR: usp0006zwy with only 0 past earthquakes available.
# Error processing event ID usp0006zy0: PAST EARTHQUAKE ERROR: usp0006zy0 with only 0 past earthquakes available.
# Error processing event ID usp0006zy5: PAST EARTHQUAKE ERROR: usp0006zy5 with only 0 past earthquakes available.
# Error processing event ID usp00070a7: PAST EARTHQUAKE ERROR: usp00070a7 with only 1 past earthquakes available.
# Error processing event ID usp00070ak: PAST EARTHQUAKE ERROR: usp00070ak with only 3 past earthquakes available.
# Error processing event ID usp00070bg: PAST EARTHQUAKE ERROR: usp00070bg with only 3 past earthquakes available.
# Error processing event ID usp00070dx: PAST EARTHQUAKE ERROR: usp00070dx with only 1 past earthquakes available.
# Error processing event ID usp00070h8: PAST EARTHQUAKE ERROR: usp00070h8 with only 1 past earthquakes available.
# Error processing event ID usp00070r7: PAST EARTHQUAKE ERROR: usp00070r7 with only 0 past earthquakes available.
# Error processing event ID usp00070uq: PAST EARTHQUAKE ERROR: usp00070uq with only 0 past earthquakes available.
# Error processing event ID usp00070xx: PAST EARTHQUAKE ERROR: usp00070xx with only 0 past earthquakes available.
# Error processing event ID usp0007147: PAST EARTHQUAKE ERROR: usp0007147 with only 1 past earthquakes available.
# Error processing event ID usp000716d: PAST EARTHQUAKE ERROR: usp000716d with only 0 past earthquakes available.
# Error processing event ID usp00071em: PAST EARTHQUAKE ERROR: usp00071em with only 0 past earthquakes available.
# Error processing event ID usp00071h2: PAST EARTHQUAKE ERROR: usp00071h2 with only 3 past earthquakes available.
# Error processing event ID usp00071xa: PAST EARTHQUAKE ERROR: usp00071xa with only 0 past earthquakes available.
# Error processing event ID usp00071xp: PAST EARTHQUAKE ERROR: usp00071xp with only 0 past earthquakes available.
# Error processing event ID usp00072a1: PAST EARTHQUAKE ERROR: usp00072a1 with only 3 past earthquakes available.
# Error processing event ID usp00072b9: PAST EARTHQUAKE ERROR: usp00072b9 with only 1 past earthquakes available.
# Error processing event ID usp00072bf: PAST EARTHQUAKE ERROR: usp00072bf with only 4 past earthquakes available.
# Error processing event ID usp00072bj: PAST EARTHQUAKE ERROR: usp00072bj with only 3 past earthquakes available.
# Error processing event ID usp00072bk: PAST EARTHQUAKE ERROR: usp00072bk with only 6 past earthquakes available.
# Error processing event ID usp00072fw: PAST EARTHQUAKE ERROR: usp00072fw with only 1 past earthquakes available.
# Error processing event ID usp00072k0: PAST EARTHQUAKE ERROR: usp00072k0 with only 0 past earthquakes available.
# Error processing event ID usp000730r: PAST EARTHQUAKE ERROR: usp000730r with only 1 past earthquakes available.
# Error processing event ID usp00073c5: PAST EARTHQUAKE ERROR: usp00073c5 with only 1 past earthquakes available.
# Error processing event ID usp00073td: PAST EARTHQUAKE ERROR: usp00073td with only 0 past earthquakes available.
# Error processing event ID usp000740g: PAST EARTHQUAKE ERROR: usp000740g with only 0 past earthquakes available.
# Error processing event ID usp0007478: PAST EARTHQUAKE ERROR: usp0007478 with only 0 past earthquakes available.
# Error processing event ID usp000747f: PAST EARTHQUAKE ERROR: usp000747f with only 0 past earthquakes available.
# Error processing event ID usp000749g: PAST EARTHQUAKE ERROR: usp000749g with only 0 past earthquakes available.
# Error processing event ID usp00074gd: PAST EARTHQUAKE ERROR: usp00074gd with only 1 past earthquakes available.
# Error processing event ID usp00074kt: PAST EARTHQUAKE ERROR: usp00074kt with only 0 past earthquakes available.
# Error processing event ID usp00074ns: PAST EARTHQUAKE ERROR: usp00074ns with only 2 past earthquakes available.
# Error processing event ID usp00074vc: PAST EARTHQUAKE ERROR: usp00074vc with only 0 past earthquakes available.
# Error processing event ID usp000751d: PAST EARTHQUAKE ERROR: usp000751d with only 1 past earthquakes available.
# Error processing event ID usp000753d: PAST EARTHQUAKE ERROR: usp000753d with only 0 past earthquakes available.
# Error processing event ID usp00075bd: PAST EARTHQUAKE ERROR: usp00075bd with only 0 past earthquakes available.
# Error processing event ID usp00075cz: PAST EARTHQUAKE ERROR: usp00075cz with only 1 past earthquakes available.
# Error processing event ID usp00075d0: PAST EARTHQUAKE ERROR: usp00075d0 with only 4 past earthquakes available.
# Error processing event ID usp00075d5: PAST EARTHQUAKE ERROR: usp00075d5 with only 3 past earthquakes available.
# Error processing event ID usp00075db: PAST EARTHQUAKE ERROR: usp00075db with only 4 past earthquakes available.
# Error processing event ID usp00075dg: PAST EARTHQUAKE ERROR: usp00075dg with only 2 past earthquakes available.
# Error processing event ID usp00075dw: PAST EARTHQUAKE ERROR: usp00075dw with only 6 past earthquakes available.
# Error processing event ID usp00075g6: PAST EARTHQUAKE ERROR: usp00075g6 with only 5 past earthquakes available.
# Error processing event ID usp00075gf: PAST EARTHQUAKE ERROR: usp00075gf with only 0 past earthquakes available.
# Error processing event ID usp000760d: PAST EARTHQUAKE ERROR: usp000760d with only 2 past earthquakes available.
# Error processing event ID usp000760t: PAST EARTHQUAKE ERROR: usp000760t with only 0 past earthquakes available.
# Error processing event ID usp000763t: PAST EARTHQUAKE ERROR: usp000763t with only 5 past earthquakes available.
# Error processing event ID usp00076e6: PAST EARTHQUAKE ERROR: usp00076e6 with only 0 past earthquakes available.
# ...
# Error processing event ID us6000ip3f: PAST EARTHQUAKE ERROR: us6000ip3f with only 7 past earthquakes available.
# Error processing event ID us6000iq08: PAST EARTHQUAKE ERROR: us6000iq08 with only 6 past earthquakes available.
# Error processing event ID us6000iq9e: PAST EARTHQUAKE ERROR: us6000iq9e with only 2 past earthquakes available.
# Error processing event ID us6000iv6c: PAST EARTHQUAKE ERROR: us6000iv6c with only 12 past earthquakes available.
# Error processing event ID us6000iwds: PAST EARTHQUAKE ERROR: us6000iwds with only 5 past earthquakes available.
# Error processing event ID us7000ilwt: PAST EARTHQUAKE ERROR: us7000ilwt with only 0 past earthquakes available.
# Error processing event ID us7000imgl: PAST EARTHQUAKE ERROR: us7000imgl with only 3 past earthquakes available.
# Error processing event ID us7000ip7p: PAST EARTHQUAKE ERROR: us7000ip7p with only 15 past earthquakes available.
# Error processing event ID us7000ipkm: PAST EARTHQUAKE ERROR: us7000ipkm with only 10 past earthquakes available.
# Error processing event ID us7000irjd: PAST EARTHQUAKE ERROR: us7000irjd with only 1 past earthquakes available.
# Error processing event ID us6000j83l: PAST EARTHQUAKE ERROR: us6000j83l with only 14 past earthquakes available.
# Error processing event ID us6000j901: PAST EARTHQUAKE ERROR: us6000j901 with only 5 past earthquakes available.
# Error processing event ID us6000ja1a: PAST EARTHQUAKE ERROR: us6000ja1a with only 16 past earthquakes available.
# Error processing event ID nc73821036: PAST EARTHQUAKE ERROR: nc73821036 with only 19 past earthquakes available.
# Error processing event ID us6000jbf0: PAST EARTHQUAKE ERROR: us6000jbf0 with only 11 past earthquakes available.
# Error processing event ID us7000j4mj: PAST EARTHQUAKE ERROR: us7000j4mj with only 9 past earthquakes available.
# Error processing event ID us6000jkpr: PAST EARTHQUAKE ERROR: us6000jkpr with only 2 past earthquakes available.
# Error processing event ID us6000jlh9: PAST EARTHQUAKE ERROR: us6000jlh9 with only 8 past earthquakes available.
# Error processing event ID us6000jmhm: PAST EARTHQUAKE ERROR: us6000jmhm with only 9 past earthquakes available.
# Error processing event ID us6000jp76: PAST EARTHQUAKE ERROR: us6000jp76 with only 7 past earthquakes available.
# Error processing event ID us6000jrjl: PAST EARTHQUAKE ERROR: us6000jrjl with only 17 past earthquakes available.
# Error processing event ID us7000jgmu: PAST EARTHQUAKE ERROR: us7000jgmu with only 8 past earthquakes available.
# Error processing event ID us7000jgr1: PAST EARTHQUAKE ERROR: us7000jgr1 with only 17 past earthquakes available.
# Error processing event ID us7000jhtd: PAST EARTHQUAKE ERROR: us7000jhtd with only 2 past earthquakes available.
# Error processing event ID us7000jhuv: PAST EARTHQUAKE ERROR: us7000jhuv with only 5 past earthquakes available.
# Error processing event ID us7000ji2e: PAST EARTHQUAKE ERROR: us7000ji2e with only 3 past earthquakes available.
# Error processing event ID us7000jlkb: PAST EARTHQUAKE ERROR: us7000jlkb with only 5 past earthquakes available.
# Error processing event ID us6000k09q: PAST EARTHQUAKE ERROR: us6000k09q with only 15 past earthquakes available.
# Error processing event ID us6000k1mn: PAST EARTHQUAKE ERROR: us6000k1mn with only 0 past earthquakes available.
# Error processing event ID us6000k1x2: PAST EARTHQUAKE ERROR: us6000k1x2 with only 3 past earthquakes available.
# Error processing event ID us6000k20g: PAST EARTHQUAKE ERROR: us6000k20g with only 8 past earthquakes available.
# Error processing event ID us6000k2kk: PAST EARTHQUAKE ERROR: us6000k2kk with only 3 past earthquakes available.
# Error processing event ID us6000k42y: PAST EARTHQUAKE ERROR: us6000k42y with only 4 past earthquakes available.
# Error processing event ID us6000k57x: PAST EARTHQUAKE ERROR: us6000k57x with only 10 past earthquakes available.
# Error processing event ID us6000k9mb: PAST EARTHQUAKE ERROR: us6000k9mb with only 12 past earthquakes available.
# Error processing event ID us6000k9rh: PAST EARTHQUAKE ERROR: us6000k9rh with only 18 past earthquakes available.
# Error processing event ID us6000kbtf: PAST EARTHQUAKE ERROR: us6000kbtf with only 14 past earthquakes available.
# Error processing event ID us6000kbtz: PAST EARTHQUAKE ERROR: us6000kbtz with only 15 past earthquakes available.
# Error processing event ID us6000kcnb: PAST EARTHQUAKE ERROR: us6000kcnb with only 0 past earthquakes available.
# Error processing event ID us6000kdrq: PAST EARTHQUAKE ERROR: us6000kdrq with only 3 past earthquakes available.
# Error processing event ID us7000k3n3: PAST EARTHQUAKE ERROR: us7000k3n3 with only 1 past earthquakes available.
# Error processing event ID us7000k46f: PAST EARTHQUAKE ERROR: us7000k46f with only 18 past earthquakes available.
# Error processing event ID us7000k4w1: PAST EARTHQUAKE ERROR: us7000k4w1 with only 8 past earthquakes available.
# Error processing event ID us7000k58z: PAST EARTHQUAKE ERROR: us7000k58z with only 17 past earthquakes available.
# Error processing event ID us7000k782: PAST EARTHQUAKE ERROR: us7000k782 with only 5 past earthquakes available.
# Error processing event ID us7000k7su: PAST EARTHQUAKE ERROR: us7000k7su with only 8 past earthquakes available.
# Error processing event ID us7000k94b: PAST EARTHQUAKE ERROR: us7000k94b with only 14 past earthquakes available.
# Error processing event ID us7000k96n: PAST EARTHQUAKE ERROR: us7000k96n with only 4 past earthquakes available.
# Error processing event ID us7000k9f0: PAST EARTHQUAKE ERROR: us7000k9f0 with only 0 past earthquakes available.
# Error processing event ID us7000kane: PAST EARTHQUAKE ERROR: us7000kane with only 4 past earthquakes available.
# Error processing event ID us6000knj0: PAST EARTHQUAKE ERROR: us6000knj0 with only 0 past earthquakes available.
# Error processing event ID us7000kfnc: PAST EARTHQUAKE ERROR: us7000kfnc with only 19 past earthquakes available.
# Error processing event ID us7000kgje: PAST EARTHQUAKE ERROR: us7000kgje with only 4 past earthquakes available.
# Error processing event ID us7000kgpb: PAST EARTHQUAKE ERROR: us7000kgpb with only 8 past earthquakes available.
# Error processing event ID us7000ki6k: PAST EARTHQUAKE ERROR: us7000ki6k with only 6 past earthquakes available.
# Error processing event ID us6000kwl6: PAST EARTHQUAKE ERROR: us6000kwl6 with only 1 past earthquakes available.
# Error processing event ID us6000kytu: PAST EARTHQUAKE ERROR: us6000kytu with only 6 past earthquakes available.
# Error processing event ID us6000kyty: PAST EARTHQUAKE ERROR: us6000kyty with only 5 past earthquakes available.
# Error processing event ID us6000kz5s: PAST EARTHQUAKE ERROR: us6000kz5s with only 18 past earthquakes available.
# Error processing event ID us6000kzv3: PAST EARTHQUAKE ERROR: us6000kzv3 with only 0 past earthquakes available.
# Error processing event ID us7000krsj: PAST EARTHQUAKE ERROR: us7000krsj with only 1 past earthquakes available.
# Error processing event ID us7000ksrl: PAST EARTHQUAKE ERROR: us7000ksrl with only 3 past earthquakes available.
# Error processing event ID us7000kub5: PAST EARTHQUAKE ERROR: us7000kub5 with only 4 past earthquakes available.
# Error processing event ID us7000kubt: PAST EARTHQUAKE ERROR: us7000kubt with only 3 past earthquakes available.
# Error processing event ID us7000kwaz: PAST EARTHQUAKE ERROR: us7000kwaz with only 5 past earthquakes available.
# Error processing event ID us7000kwg2: PAST EARTHQUAKE ERROR: us7000kwg2 with only 3 past earthquakes available.
# Error processing event ID us7000kwm6: PAST EARTHQUAKE ERROR: us7000kwm6 with only 16 past earthquakes available.
# Error processing event ID us7000kx7t: PAST EARTHQUAKE ERROR: us7000kx7t with only 19 past earthquakes available.
# Error processing event ID us6000lbgs: PAST EARTHQUAKE ERROR: us6000lbgs with only 10 past earthquakes available.
# Error processing event ID us6000lch5: PAST EARTHQUAKE ERROR: us6000lch5 with only 7 past earthquakes available.
# Error processing event ID us6000lciv: PAST EARTHQUAKE ERROR: us6000lciv with only 10 past earthquakes available.
# Error processing event ID us6000lcnc: PAST EARTHQUAKE ERROR: us6000lcnc with only 5 past earthquakes available.
# Error processing event ID us6000lcp1: PAST EARTHQUAKE ERROR: us6000lcp1 with only 3 past earthquakes available.
# Error processing event ID us6000lczf: PAST EARTHQUAKE ERROR: us6000lczf with only 12 past earthquakes available.
# Error processing event ID us6000ld0f: PAST EARTHQUAKE ERROR: us6000ld0f with only 1 past earthquakes available.
# Error processing event ID us6000ldbb: PAST EARTHQUAKE ERROR: us6000ldbb with only 8 past earthquakes available.
# Error processing event ID us6000lddt: PAST EARTHQUAKE ERROR: us6000lddt with only 9 past earthquakes available.
# Error processing event ID us6000leyu: PAST EARTHQUAKE ERROR: us6000leyu with only 2 past earthquakes available.
# Error processing event ID us6000lfvj: PAST EARTHQUAKE ERROR: us6000lfvj with only 4 past earthquakes available.
# Error processing event ID us6000lfvn: PAST EARTHQUAKE ERROR: us6000lfvn with only 0 past earthquakes available.
# Error processing event ID us6000lgpg: PAST EARTHQUAKE ERROR: us6000lgpg with only 4 past earthquakes available.
# Error processing event ID us6000lgrt: PAST EARTHQUAKE ERROR: us6000lgrt with only 12 past earthquakes available.
# Error processing event ID us7000l6k4: PAST EARTHQUAKE ERROR: us7000l6k4 with only 15 past earthquakes available.
# Error processing event ID us7000l9ip: PAST EARTHQUAKE ERROR: us7000l9ip with only 14 past earthquakes available.
# Error processing event ID us7000la13: PAST EARTHQUAKE ERROR: us7000la13 with only 3 past earthquakes available.
# Error processing event ID us6000lphm: PAST EARTHQUAKE ERROR: us6000lphm with only 16 past earthquakes available.
# Error processing event ID us6000lqf9: PAST EARTHQUAKE ERROR: us6000lqf9 with only 4 past earthquakes available.
# Error processing event ID us6000lqk3: PAST EARTHQUAKE ERROR: us6000lqk3 with only 7 past earthquakes available.
# Error processing event ID us6000lqqc: PAST EARTHQUAKE ERROR: us6000lqqc with only 6 past earthquakes available.
# Error processing event ID us7000lff4: PAST EARTHQUAKE ERROR: us7000lff4 with only 7 past earthquakes available.
# Error processing event ID us7000lfgr: PAST EARTHQUAKE ERROR: us7000lfgr with only 1 past earthquakes available.
# Error processing event ID us7000lfif: PAST EARTHQUAKE ERROR: us7000lfif with only 17 past earthquakes available.
# Error processing event ID us7000lfj2: PAST EARTHQUAKE ERROR: us7000lfj2 with only 18 past earthquakes available.
# Error processing event ID us7000lfk5: PAST EARTHQUAKE ERROR: us7000lfk5 with only 15 past earthquakes available.
# Error processing event ID us7000lfkh: PAST EARTHQUAKE ERROR: us7000lfkh with only 14 past earthquakes available.
# Error processing event ID us7000lfui: PAST EARTHQUAKE ERROR: us7000lfui with only 4 past earthquakes available.
# Error processing event ID us7000lfwj: PAST EARTHQUAKE ERROR: us7000lfwj with only 13 past earthquakes available.
# Error processing event ID us7000lh50: PAST EARTHQUAKE ERROR: us7000lh50 with only 0 past earthquakes available.
# Error processing event ID us7000lhxd: PAST EARTHQUAKE ERROR: us7000lhxd with only 6 past earthquakes available.
# Error processing event ID us7000ljhg: PAST EARTHQUAKE ERROR: us7000ljhg with only 3 past earthquakes available.
# Error processing event ID us7000ljvg: PAST EARTHQUAKE ERROR: us7000ljvg with only 0 past earthquakes available.
# Error processing event ID us7000ll46: PAST EARTHQUAKE ERROR: us7000ll46 with only 7 past earthquakes available.
# Error processing event ID us6000m0xm: PAST EARTHQUAKE ERROR: us6000m0xm with only 6 past earthquakes available.
# Error processing event ID us6000m0xt: PAST EARTHQUAKE ERROR: us6000m0xt with only 6 past earthquakes available.
# Error processing event ID us6000m0y9: PAST EARTHQUAKE ERROR: us6000m0y9 with only 10 past earthquakes available.
# Error processing event ID us6000m0ya: PAST EARTHQUAKE ERROR: us6000m0ya with only 16 past earthquakes available.
# Error processing event ID us6000m2ny: PAST EARTHQUAKE ERROR: us6000m2ny with only 5 past earthquakes available.
# Error processing event ID ak024jyw3sk: PAST EARTHQUAKE ERROR: ak024jyw3sk with only 0 past earthquakes available.
# Error processing event ID us7000luai: PAST EARTHQUAKE ERROR: us7000luai with only 8 past earthquakes available.
# Error processing event ID us7000ly6w: PAST EARTHQUAKE ERROR: us7000ly6w with only 0 past earthquakes available.
# Error processing event ID us7000lz5f: PAST EARTHQUAKE ERROR: us7000lz5f with only 6 past earthquakes available.
# Error processing event ID us7000m3ud: PAST EARTHQUAKE ERROR: us7000m3ud with only 1 past earthquakes available.
# Error processing event ID us6000mj1l: PAST EARTHQUAKE ERROR: us6000mj1l with only 4 past earthquakes available.
# Error processing event ID us7000m875: PAST EARTHQUAKE ERROR: us7000m875 with only 14 past earthquakes available.
# Error processing event ID us7000m98g: PAST EARTHQUAKE ERROR: us7000m98g with only 5 past earthquakes available.
# Error processing event ID us7000m9bq: PAST EARTHQUAKE ERROR: us7000m9bq with only 4 past earthquakes available.
# Error processing event ID us7000mcb1: PAST EARTHQUAKE ERROR: us7000mcb1 with only 1 past earthquakes available.
# Error processing event ID us7000mcpi: PAST EARTHQUAKE ERROR: us7000mcpi with only 3 past earthquakes available.
# Error processing event ID us7000mcrs: PAST EARTHQUAKE ERROR: us7000mcrs with only 2 past earthquakes available.
# Error processing event ID us7000mcxe: PAST EARTHQUAKE ERROR: us7000mcxe with only 0 past earthquakes available.
# Error processing event ID us6000mu8k: PAST EARTHQUAKE ERROR: us6000mu8k with only 13 past earthquakes available.
# Error processing event ID us6000mvya: PAST EARTHQUAKE ERROR: us6000mvya with only 5 past earthquakes available.
# Error processing event ID us6000mwf5: PAST EARTHQUAKE ERROR: us6000mwf5 with only 3 past earthquakes available.
# Error processing event ID us6000my20: PAST EARTHQUAKE ERROR: us6000my20 with only 17 past earthquakes available.
# Error processing event ID us7000mnu8: PAST EARTHQUAKE ERROR: us7000mnu8 with only 10 past earthquakes available.
# Error processing event ID us7000mqp4: PAST EARTHQUAKE ERROR: us7000mqp4 with only 1 past earthquakes available.
# Error processing event ID us7000mrv4: PAST EARTHQUAKE ERROR: us7000mrv4 with only 13 past earthquakes available.
# Error processing event ID us7000mx3m: PAST EARTHQUAKE ERROR: us7000mx3m with only 11 past earthquakes available.
# Error processing event ID us7000mxl6: PAST EARTHQUAKE ERROR: us7000mxl6 with only 11 past earthquakes available.
# Error processing event ID us7000mxmu: PAST EARTHQUAKE ERROR: us7000mxmu with only 0 past earthquakes available.
# Error processing event ID us7000mxmx: PAST EARTHQUAKE ERROR: us7000mxmx with only 7 past earthquakes available.
# Error processing event ID us7000mzzc: PAST EARTHQUAKE ERROR: us7000mzzc with only 6 past earthquakes available.
# Error processing event ID us7000n0ka: PAST EARTHQUAKE ERROR: us7000n0ka with only 1 past earthquakes available.
# Error processing event ID us6000nhqc: PAST EARTHQUAKE ERROR: us6000nhqc with only 19 past earthquakes available.
# Error processing event ID us6000nith: PAST EARTHQUAKE ERROR: us6000nith with only 7 past earthquakes available.
# Error processing event ID us6000nj9s: PAST EARTHQUAKE ERROR: us6000nj9s with only 1 past earthquakes available.
# Error processing event ID us7000n7n8: PAST EARTHQUAKE ERROR: us7000n7n8 with only 17 past earthquakes available.
# Error processing event ID us7000n7v7: PAST EARTHQUAKE ERROR: us7000n7v7 with only 12 past earthquakes available.
# Error processing event ID us7000n8ki: PAST EARTHQUAKE ERROR: us7000n8ki with only 19 past earthquakes available.
# Error processing event ID us7000n9fn: PAST EARTHQUAKE ERROR: us7000n9fn with only 4 past earthquakes available.
# Error processing event ID us6000nncs: PAST EARTHQUAKE ERROR: us6000nncs with only 11 past earthquakes available.
# Error processing event ID us6000nnlx: PAST EARTHQUAKE ERROR: us6000nnlx with only 6 past earthquakes available.
# 651
